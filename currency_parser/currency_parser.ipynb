# %%
import requests
from bs4 import BeautifulSoup

page =requests.get('https://cbr.ru/currency_base/daily/')
soup=BeautifulSoup(page.content, 'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="ru" name="zoom:lang"/>
# <meta content="Thu, 15 Jul 2021 21:00:00 GMT" name="zoom:last-modified"/>
# <title>Официальные курсы валют на заданную дату, устанавливаемые ежедневно | Банк России</title>
# <meta content="/common/images/share-1.jpg" property="og:image"/>
# <link href="/common/libs/jquery-ui/jquery-ui.min.css?v=v599209514" media="all" rel="stylesheet" type="text/css"/>
# <!--[if IE 9]><link rel="stylesheet" type="text/css" href="/common/style/main-ie9.css?v=v1440262859" media="all"><![endif]-->
# <!--[if gt IE 9]><!--><link href="/common/style/main.css?v=v1370805195" media="all" rel="stylesheet" type="text/css"/><!--<![endif]-->
# ...

# %%
title=soup.title.text
title
# Out:
# 'Официальные курсы валют на заданную дату, устанавливаемые ежедневно | Банк России'

# %%
all_td=soup.find_all('tr')
all_td
# Out:
# [<tr>
#  <th>Цифр. код</th>
#  <th>Букв. код</th>
#  <th>Единиц</th>
#  <th>Валюта</th>
#  <th>Курс</th>
#  </tr>,
#  <tr>
#  <td>036</td>
#  <td>AUD</td>
#  <td>1</td>
#  <td>Австралийский доллар</td>
#  <td>55,1421</td>
#  </tr>,
#  <tr>
#  <td>944</td>
#  <td>AZN</td>
#  <td>1</td>
#  <td>Азербайджанский манат</td>
#  <td>43,6525</td>
#  </tr>,
#  <tr>
#  <td>051</td>
#  <td>AMD</td>
#  <td>100</td>
#  <td>Армянских драмов</td>
#  <td>14,8972</td>
#  </tr>,
#  <tr>
#  <td>933</td>
#  <td>BYN</td>
#  <td>1</td>
#  <td>Белорусский рубль</td>
#  <td>29,2913</td>
#  </tr>,
#  <tr>
#  <td>975</td>
#  <td>BGN</td>
#  <td>1</td>
#  <td>Болгарский лев</td>
#  <td>44,7698</td>
#  </tr>,
#  <tr>
#  <td>986</td>
#  <td>BRL</td>
#  <td>1</td>
#  <td>Бразильский реал</td>
#  <td>14,5087</td>
#  </tr>,
#  <tr>
#  <td>348</td>
#  <td>HUF</td>
#  <td>100</td>
#  <td>Венгерских форинтов</td>
#  <td>24,3701</td>
#  </tr>,
#  <tr>
#  <td>410</td>
#  <td>KRW</td>
#  <td>1000</td>
# ...

# %%
list_cur=[]
headings=['Цифровой код', 'Буквенный код', 'Единицы', 'Валюта', 'Курс']
global_file={}
for item in all_td:
    item_text=item.text.strip().split('\n')
    list_cur.append(item_text)
list_curr=list_cur[1:]
list_curr
# Out:
# [['036', 'AUD', '1', 'Австралийский доллар', '55,1421'],
#  ['944', 'AZN', '1', 'Азербайджанский манат', '43,6525'],
#  ['051', 'AMD', '100', 'Армянских драмов', '14,8972'],
#  ['933', 'BYN', '1', 'Белорусский рубль', '29,2913'],
#  ['975', 'BGN', '1', 'Болгарский лев', '44,7698'],
#  ['986', 'BRL', '1', 'Бразильский реал', '14,5087'],
#  ['348', 'HUF', '100', 'Венгерских форинтов', '24,3701'],
#  ['410', 'KRW', '1000', 'Вон Республики Корея', '65,0059'],
#  ['344', 'HKD', '10', 'Гонконгских долларов', '95,4660'],
#  ['208', 'DKK', '1', 'Датская крона', '11,7731'],
#  ['840', 'USD', '1', 'Доллар США', '74,1656'],
#  ['978', 'EUR', '1', 'Евро', '87,5673'],
#  ['356', 'INR', '100', 'Индийских рупий', '99,4344'],
#  ['398', 'KZT', '100', 'Казахстанских тенге', '17,3712'],
#  ['124', 'CAD', '1', 'Канадский доллар', '58,9645'],
#  ['417', 'KGS', '100', 'Киргизских сомов', '87,4703'],
#  ['156', 'CNY', '1', 'Китайский юань', '11,4673'],
# ...

# %%
data=[]
for items in list_curr:
    data.append(dict(zip(headings,items)))
            
data
# Out:
# [{'Цифровой код': '036',
#   'Буквенный код': 'AUD',
#   'Единицы': '1',
#   'Валюта': 'Австралийский доллар',
#   'Курс': '55,1421'},
#  {'Цифровой код': '944',
#   'Буквенный код': 'AZN',
#   'Единицы': '1',
#   'Валюта': 'Азербайджанский манат',
#   'Курс': '43,6525'},
#  {'Цифровой код': '051',
#   'Буквенный код': 'AMD',
#   'Единицы': '100',
#   'Валюта': 'Армянских драмов',
#   'Курс': '14,8972'},
#  {'Цифровой код': '933',
#   'Буквенный код': 'BYN',
#   'Единицы': '1',
#   'Валюта': 'Белорусский рубль',
#   'Курс': '29,2913'},
#  {'Цифровой код': '975',
#   'Буквенный код': 'BGN',
#   'Единицы': '1',
#   'Валюта': 'Болгарский лев',
#   'Курс': '44,7698'},
#  {'Цифровой код': '986',
#   'Буквенный код': 'BRL',
#   'Единицы': '1',
#   'Валюта': 'Бразильский реал',
#   'Курс': '14,5087'},
#  {'Цифровой код': '348',
#   'Буквенный код': 'HUF',
#   'Единицы': '100',
#   'Валюта': 'Венгерских форинтов',
#   'Курс': '24,3701'},
#  {'Цифровой код': '410',
# ...

# %%
with open("data_file.json", "w",encoding='utf-8') as write_file:
    json.dump(data, write_file, sort_keys=True, indent=4)
